# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
nombre = "deisy"
edad = 25
ciudad = "luque"
print("Mi nombre es",nombre,"tengo", edad,"vivo en la cuidad de", cuidad)
# Out:
# Mi nombre es deisy tengo 25 vivo en la cuidad de luque

# %% [markdown]
# ## Challenge 🤺 - 10m
#
# Suma: asignar dos números en dos variables diferentes `cantidad_de_manzanas` y `cantidad_de_naranjas`. Luego sumar ambas variables en `cantidad_de_frutas`. Imprimir la última variable.
#
# Resta: asignar un valor numérico a la variable `frutas_vendidas`. Luego, asignar la resta entre `cantidad_de_frutas` y `frutas_vendidas` a la variable `frutas_restantes`. Imprimir la última variable.

# %%
cantidad_de_manzanas = 19
cantidad_de_naranjas = 17
cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas
print (cantidad_de_frutas)
# Out:
# 36

# %% [markdown]
# ## Challenge 🤺 - 10m
#
# Asignar el nombre y el apellido de tu compañera/o a las variables `nombre` y `apellido`. Luego, `imprimir` una frase, utilizando las variables.
# EJEMPLO: "Hola. Me llamo Claudia Melgarejo. Mucho gusto."

# %%
# paso 1
nombre = "Kevin"
apellido = "Bell0"

# paso 2
print (f"Hola. me llamo", nombre, "y mi apellido es", apellido, ", Mucho gusto")
# Out:
# Hola. me llamo Kevin y mi apellido es Bell0 , Mucho gusto

# %% [markdown]
# ### Challenge 🤺 - 8m
#
# `Solicitar al usuario ingresar` dos números y almacenarlos en dos variables. Luego, imprimir la suma de los dos números.

# %%
usuario1 = int(input("cantidad de cuotas restantes"))
usuario2 = int(input("cantidad de cuotas restantes"))
suma = (usuario1 + usuario2)
print (f'le quedan {suma}')
print (type (suma))
# Out:
# le quedan 9
# <class 'int'>

# %% [markdown]
# ## Challenge 🤺 - 10m
#
# `Crear` una función de un proceso que se les ocurra que tenga `varios` pasos.
#
# - Ejecutar la función 3 veces.

# %%
# preparacion 
def prepara_un_cafe():
    print("se tomo su pedido")
    print("su pedido esta casi listo")
    print("puede pasar a retirar su pedido")

#llamar a la funcion

prepara_un_cafe()
prepara_un_cafe()
prepara_un_cafe()
# Out:
# se tomo su pedido
# su pedido esta casi listo
# puede pasar a retirar su pedido
# se tomo su pedido
# su pedido esta casi listo
# puede pasar a retirar su pedido
# se tomo su pedido
# su pedido esta casi listo
# puede pasar a retirar su pedido

# %% [markdown]
# ## Challenge 🤺 - 25m
#
# Escribir una funcion que nos pregunte las caracteristicas de un elemento a comprar e imprima el elemento con sus caracteristicas.

# %%
marca1 = " oxva" 
marca2 = " vaporesso" 


def que_marca_de_cartucho_busca(cartucho1, cartucho2):
    print(f"necesito un cartucho de la marca{cartucho1}")
    print(f"necesito un cartucho de la marca{cartucho2}")
que_marca_de_cartucho_busca(marca1, marca2)
# Out:
# necesito un cartucho de la marca oxva
# necesito un cartucho de la marca vaporesso

# %%
def marca_de_auto():
    print = input(f"que marca de vehiculo busca{opcion1}")
    print = input(f"que tamaño de vehiculo prefiere{opcion2}")
    print =input(f"que color de vehiculo le gustaria{opcion3}")







marca_de_auto(opcion1, opcion2, opcion3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 12
#       3     print = input(f"que tamaño de vehiculo prefiere{opcion2}")
#       4     print =input(f"que color de vehiculo le gustaria{opcion3}")
# ---> 12 marca_de_auto(opcion1, opcion2, opcion3)
#
# NameError: name 'opcion1' is not defined
